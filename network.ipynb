# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

nf = pd.read_csv(r'C:\Users\Dorottya\Documents\python\nodes.csv')
ef = pd.read_csv(r'C:\Users\Dorottya\Documents\python\edges.csv')
#ef = [('11', '21')]

G = nx.Graph()

#G.add_nodes_from(nf)
#G.add_nodes_from([11,12,13,14,15,16,17,18])
#G.add_nodes_from([21,22,23,24,25,26,27,28])

#G.add_edges_from(ef)
#G.add_edge(1,2)
#G.add_edge(1,3)
#G.add_edges_from([(1, 2, {'color': 'blue'}), (2, 3, {'weight': 8})])

#G.add_weighted_edges_from(ef)

G.add_weighted_edges_from([
    (11, 21, 6),
    (11, 22, 5),
    (11, 23, 4),
    (11, 24, 3),
    (11, 25, 3),
    (11, 26, 2),
    #(11, 27, 0),
    (11, 28, 1)
])

G.add_weighted_edges_from([
    (12, 21, 7),
    (12, 22, 5),
    (12, 23, 2),
    (12, 24, 2),
    (12, 25, 1),
    (12, 26, 3),
    (12, 27, 1)
    #,(12, 28, 0)
])

G.add_weighted_edges_from([
    (13, 21, 7),
    (13, 22, 11),
    (13, 23, 4),
    (13, 24, 3),
    (13, 25, 2),
    (13, 26, 2),
    (13, 27, 3),
    (13, 28, 4)
])
G.add_weighted_edges_from([
    (14, 21, 5),
    (14, 22, 4),
    (14, 23, 5),
    (14, 24, 4),
    (14, 25, 1),
    (14, 26, 1),
    (14, 27, 1)
    #,(14, 28, 0)
])
G.add_weighted_edges_from([
    (15, 21, 7),
    (15, 22, 1),
    (15, 23, 1),
    (15, 24, 2),
    (15, 25, 2),
    #(15, 26, 0),
    (15, 27, 1),
    (15, 28, 1)
])
G.add_weighted_edges_from([
    (16, 21, 2),
    (16, 22, 2),
    (16, 23, 5),
    (16, 24, 2),
   # (16, 25, 0),
    (16, 26, 1),
    (16, 27, 3)
   # ,(16, 28, 0)
])
G.add_weighted_edges_from([
    (17, 21, 2),
    (17, 22, 1),
    (17, 23, 2),
  #  (17, 24, 0),
  #  (17, 25, 0),
  #  (17, 26, 0),
    (17, 27, 1)
   # ,  (17, 28, 0)
])
G.add_weighted_edges_from([
  #  (18, 21, 0),
    (18, 22, 1),
    (18, 23, 1),
    (18, 24, 2),
  #  (18, 25, 0),
  #  (18, 26, 0),
    (18, 27, 2),
  #  (18, 28, 0)
])
G.add_weighted_edges_from([
    (21, 31, 13),
    (21, 32, 2),
    (21, 33, 10),
    (21, 34, 3),
    (21, 35, 2),
    (21, 36, 4),
    (21, 37, 2),
  #  (21, 38, 0)
])
G.add_weighted_edges_from([
    (22, 31, 6),
    (22, 32, 1),
    (22, 33, 9),
    (22, 34, 3),
    (22, 35, 2),
    (22, 36, 2),
    (22, 37, 1),
   # (22, 38, 0)
])
G.add_weighted_edges_from([
    (23, 31, 4),
    (23, 32, 6),
  #  (23, 33, 0),
    (23, 34, 1),
    (23, 35, 2),
    (23, 36, 4),
  #  (23, 37, 0),
    (23, 38, 3)
])
G.add_weighted_edges_from([
    (24, 31, 7),
   # (24, 32, 0),
    (24, 33, 4),
    (24, 34, 1),
    (24, 35, 1)
  #  , (24, 36, 0),
  #  (24, 37, 0),
  #  (24, 38, 0)
])
G.add_weighted_edges_from([
    (25, 31, 4),
    (25, 32, 2),
   # (25, 33, 0),
   # (25, 34, 0),
    (25, 35, 1),
    (25, 36, 1)
   # , (25, 37, 0),
   # (25, 38, 0)
])
G.add_weighted_edges_from([
    (26, 31, 4),
    (26, 32, 3),
  #  (26, 33, 0),
  #  (26, 34, 0),
    (26, 35, 1),
  #  (26, 36, 0),
  #  (26, 37, 0),
    (26, 38, 1)
])

G.add_weighted_edges_from([
    (27, 31, 4),
   # (27, 32, 0),
    (27, 33, 2),
   # (27, 34, 0),
   # (27, 35, 0),
    (27, 36, 2),
   # (27, 37, 0),
   # (27, 38, 0)
])
G.add_weighted_edges_from([
   # (28, 31, 0),
    (28, 32, 1),
    (28, 33, 2),
    (28, 34, 1),
   # (28, 35, 0),
   # (28, 36, 0),
   # (28, 37, 0),
    (28, 38, 1)
])

G.add_weighted_edges_from([
    (11, 31, 8),
    (11, 32, 10),
    (11, 33, 6),
    (11, 34, 2),
    (11, 35, 2),
    (11, 36, 3),
  #  (11, 37, 0),
    (11, 38, 1)
])

G.add_weighted_edges_from([
    (12, 31, 8),
    (12, 32, 3),
    (12, 33, 2),
    (12, 34, 1),
    (12, 35, 1),
    (12, 36, 2),
   # (12, 37, 0),
    (12, 38, 1)
])

G.add_weighted_edges_from([
    (13, 31, 8),
    (13, 32, 3),
    (13, 33, 9),
    (13, 34, 3),
    (13, 35, 1),
    (13, 36, 2),
   # (13, 37, 0),
    (13, 38, 1)
])
G.add_weighted_edges_from([
    (14, 31, 12),
    (14, 32, 6),
    (14, 33, 4),
    (14, 34, 2),
    (14, 35, 3),
    (14, 36, 2),
    (14, 37, 1),
  #  (14, 38, 0)
])
G.add_weighted_edges_from([
    (15, 31, 6),
    (15, 32, 1),
    (15, 33, 3),
   # (15, 34, 0),
   # (15, 35, 0),
   # (15, 36, 0),
    (15, 37, 1),
    (15, 38, 1)
])
G.add_weighted_edges_from([
    (16, 31, 3),
    (16, 32, 3),
    (16, 33, 1),
   # (16, 34, 0),
    (16, 35, 1),
    (16, 36, 4),
   # (16, 37, 0),
    (16, 38, 1)
])
G.add_weighted_edges_from([
    (17, 31, 2),
    (17, 32, 1),
    (17, 33, 1),
    #(17, 34, 0),
    #(17, 35, 0),
    (17, 36, 2),
    (17, 37, 1),
    (17, 38, 1)
])
G.add_weighted_edges_from([
    (18, 31, 1),
   # (18, 32, 0),
    (18, 33, 1),
    (18, 34, 1),
    (18, 35, 1),
   # (18, 36, 0),
   # (18, 37, 0),
   # (18, 38, 0)
])

#G.add_edges(11, 26, weight=20 )


nx.draw(G, with_labels=True)
plt.savefig("simple_path.png") # save as png
plt.show()
print(G.number_of_nodes())
print(G.number_of_edges())
G.clear()
# Out:
# 24
# 138
